# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./datasets/tutorial_sleep_training_data.csv.gz")

# %%
df.head(40)
# Out:
#     time  act  sleep_phase    hr  pid
# 0      0  NaN          NaN  75.0    1
# 1      1  NaN          NaN  75.0    1
# 2      2  NaN          NaN  77.0    1
# 3      3  NaN          NaN  78.0    1
# 4      4  NaN          NaN  77.0    1
# 5      5  NaN          NaN  75.0    1
# 6      6  NaN          NaN  73.0    1
# 7      7  NaN          NaN  75.0    1
# 8      8  NaN          NaN  75.0    1
# 9      9  NaN          NaN  76.0    1
# 10    10  NaN          NaN  76.0    1
# 11    11  NaN          NaN  75.0    1
# 12    12  NaN          NaN  76.0    1
# 13    13  NaN          NaN  75.0    1
# 14    14  NaN          NaN  76.0    1
# 15    15  NaN          NaN  77.0    1
# 16    16  NaN          NaN  75.0    1
# 17    17  NaN          NaN  76.0    1
# 18    18  NaN          NaN  74.0    1
# 19    19  NaN          NaN  75.0    1
# 20    20  NaN          NaN  77.0    1
# 21    21  NaN          NaN  75.0    1
# 22    22  NaN          NaN  75.0    1
# 23    23  NaN          NaN  75.0    1
# 24    24  NaN          NaN  76.0    1
# 25    25  NaN          NaN  75.0    1
# 26    26  NaN          NaN  75.0    1
# 27    27  NaN          NaN  75.0    1
# 28    28  NaN          NaN  71.0    1
# 29    29  2.0          0.0  73.0    1
# 30    30  NaN          NaN  74.0    1
# 31    31  NaN          NaN  78.0    1
# 32    32  NaN          NaN  80.0    1
# 33    33  NaN          NaN  77.0    1
# 34    34  NaN          NaN  76.0    1
# 35    35  NaN          NaN  77.0    1
# 36    36  NaN          NaN  78.0    1
# 37    37  NaN          NaN  76.0    1
# 38    38  NaN          NaN  75.0    1
# 39    39  NaN          NaN  74.0    1

# %%
pids = list(df["pid"].unique())
print("Number of individuals:", len(pids))
# Out:
# Number of individuals: 200

# %%
df1 = df[df["pid"] == pids[10]]
df1
# Out:
#          time  act  sleep_phase    hr  pid
# 289635      0  NaN          NaN  71.0   11
# 289636      1  NaN          NaN  70.0   11
# 289637      2  NaN          NaN  70.0   11
# 289638      3  NaN          NaN  72.0   11
# 289639      4  NaN          NaN  70.0   11
# ...       ...  ...          ...   ...  ...
# 323770  34135  NaN          NaN  34.0   11
# 323771  34136  NaN          NaN  32.0   11
# 323772  34137  NaN          NaN  34.0   11
# 323773  34138  NaN          NaN  32.0   11
# 323774  34139  7.0          0.0  32.0   11
#
# [34140 rows x 5 columns]

# %%
df1.plot(x="time")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True)
df1.dropna().plot(x="time", y="act", ax=ax1, color="green")
df1.plot(x="time", y="hr",     ax=ax2, color="red")
df1.dropna().plot(x="time", y="sleep_phase",  ax=ax3)
plt.show()

# %%
def data_exploration(df, sleep_col="sleep_phase"):
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True)
    df[["time", "act"]].dropna().plot(x="time", y="act", ax=ax1, color="green")
    df[["time", "hr"]].plot(x="time", y="hr",     ax=ax2, color="red")
    df[["time", sleep_col]].dropna().plot(x="time", y=sleep_col,  ax=ax3)
    ax1.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    ax2.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    ax3.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    plt.show()

# %%
data_exploration(df[df["pid"] == pids[10]])

# %%
data_exploration(df[df["pid"] == pids[10]].dropna())

# %%
df["bin_sleep"] = (df["sleep_phase"] > 0).astype(int)

# %%
data_exploration(df[df["pid"] == pids[10]].dropna(), sleep_col="bin_sleep")

# %%
data_exploration(df[df["pid"] == pids[20]].dropna(), sleep_col="bin_sleep")
