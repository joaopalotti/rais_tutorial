# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./datasets/tutorial_sleep_training_data.csv.gz")

# %%
df.head(40)
# Out:
#     time  act  sleep_phase    hr  pid
# 0      0  NaN          NaN  74.0    0
# 1      1  NaN          NaN  74.0    0
# 2      2  NaN          NaN  75.0    0
# 3      3  NaN          NaN  77.0    0
# 4      4  NaN          NaN  76.0    0
# 5      5  NaN          NaN  76.0    0
# 6      6  NaN          NaN  75.0    0
# 7      7  NaN          NaN  76.0    0
# 8      8  NaN          NaN  76.0    0
# 9      9  NaN          NaN  74.0    0
# 10    10  NaN          NaN  75.0    0
# 11    11  NaN          NaN  76.0    0
# 12    12  NaN          NaN  77.0    0
# 13    13  NaN          NaN  75.0    0
# 14    14  NaN          NaN  76.0    0
# 15    15  NaN          NaN  78.0    0
# 16    16  NaN          NaN  76.0    0
# 17    17  NaN          NaN  77.0    0
# 18    18  NaN          NaN  75.0    0
# 19    19  NaN          NaN  76.0    0
# 20    20  NaN          NaN  75.0    0
# 21    21  NaN          NaN  76.0    0
# 22    22  NaN          NaN  74.0    0
# 23    23  NaN          NaN  74.0    0
# 24    24  NaN          NaN  76.0    0
# 25    25  NaN          NaN  74.0    0
# 26    26  NaN          NaN  74.0    0
# 27    27  NaN          NaN  72.0    0
# 28    28  NaN          NaN  73.0    0
# 29    29  2.0          0.0  71.0    0
# 30    30  NaN          NaN  74.0    0
# 31    31  NaN          NaN  78.0    0
# 32    32  NaN          NaN  77.0    0
# 33    33  NaN          NaN  79.0    0
# 34    34  NaN          NaN  76.0    0
# 35    35  NaN          NaN  76.0    0
# 36    36  NaN          NaN  76.0    0
# 37    37  NaN          NaN  76.0    0
# 38    38  NaN          NaN  76.0    0
# 39    39  NaN          NaN  75.0    0

# %%
pids = list(df["pid"].unique())
print("Number of individuals:", len(pids))
# Out:
# Number of individuals: 100

# %%
df1 = df[df["pid"] == pids[50]]
df1
# Out:
#           time  act  sleep_phase    hr  pid
# 1573317      0  NaN          NaN  53.0   50
# 1573318      1  NaN          NaN  53.0   50
# 1573319      2  NaN          NaN  55.0   50
# 1573320      3  NaN          NaN  54.0   50
# 1573321      4  NaN          NaN  55.0   50
# ...        ...  ...          ...   ...  ...
# 1611971  43649  1.0          0.0   NaN   50
# 1611972  43679  0.0          0.0   NaN   50
# 1611973  43709  0.0          0.0   NaN   50
# 1611974  43739  0.0          0.0   NaN   50
# 1611975  43769  0.0          0.0   NaN   50
#
# [38659 rows x 5 columns]

# %%
df1.dropna().plot(x="time")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True)
df1.dropna().plot(x="time", y="act", ax=ax1, color="green")
df1.plot(x="time", y="hr",     ax=ax2, color="red")
df1.dropna().plot(x="time", y="sleep_phase",  ax=ax3)
plt.show()

# %%
def data_exploration(df, sleep_col="sleep_phase"):
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True)
    df[["time", "act"]].dropna().plot(x="time", y="act", ax=ax1, color="green")
    df[["time", "hr"]].plot(x="time", y="hr",     ax=ax2, color="red")
    df[["time", sleep_col]].dropna().plot(x="time", y=sleep_col,  ax=ax3)
    ax1.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    ax2.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    ax3.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    plt.show()

# %%
data_exploration(df[df["pid"] == pids[10]])

# %%
data_exploration(df[df["pid"] == pids[10]].dropna())

# %%
df["bin_sleep"] = (df["sleep_phase"] > 0).astype(int)

# %%
data_exploration(df[df["pid"] == pids[10]].dropna(), sleep_col="bin_sleep")

# %%
data_exploration(df[df["pid"] == pids[20]].dropna(), sleep_col="bin_sleep")
